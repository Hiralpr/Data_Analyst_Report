# %% [markdown]
# ## Loading the Dimond Dataset

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
plt.style.use(['dark_background'])

import seaborn as sns
sns.set(color_codes=True)

# %%
d = sns.load_dataset('diamonds')

# %%
d.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88008315031f> in <cell line: 1>()
# ----> 1 d.head()
#
# NameError: name 'd' is not defined

# %%
d.shape

# %%
d.info()

# %% [markdown]
# ##What is the Range of caret?

# %%
print("The minimum value of caret is:", d['carat'].min())
print("The maximum value of caret is:", d['carat'].max())

# %% [markdown]
# ## In Diamond,which cut we find majority of the time?

# %%
c = d.groupby('cut')['cut'].count()

# %%
sns.barplot(x=c.index, y=c.values);

# %%
c.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bfabac8142a0> in <cell line: 1>()
# ----> 1 c.head
#
# NameError: name 'c' is not defined

# %% [markdown]
# ## In Diamond, which color we find majority of the time?

# %%
c1 = d.groupby('color')['color'].count()

# %%
sns.barplot(x=c1.index, y=c1.values);

# %%
c1
# Out:
# color
# D     6775
# E     9797
# F     9542
# G    11292
# H     8304
# I     5422
# J     2808
# Name: color, dtype: int64

# %% [markdown]
# ## What can we say about Diamond clarity? (majority of the Diamondshave best clarity or not?)

# %%
c2 = d.groupby('clarity')['clarity'].count()

# %%
sns.barplot(x=c2.index, y=c2.values);

# %%
c2
# Out:
# clarity
# IF       1790
# VVS1     3655
# VVS2     5066
# VS1      8171
# VS2     12258
# SI1     13065
# SI2      9194
# I1        741
# Name: clarity, dtype: int64

# %% [markdown]
# The Majority Clarity is SI1

# %% [markdown]
# ## Correlationbetween total depth and table

# %%
correlation = d['depth'].corr(d['table'])
print(correlation)
# Out:
# -0.295778521526582

# %%
sns.scatterplot('depth', 'table', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Range of the price

# %%
print("The minimum value of price is:", d['price'].min(), "USD")
print("The maximum value of price is:", d['price'].max(), "USD")
# Out:
# The minimum value of price is: 326 USD
# The maximum value of price is: 18823 USD

# %% [markdown]
# ## Correlation of the price with all other variables:

# %% [markdown]
# ### Correlation between Carat and Price

# %%
cor1 = d['carat'].corr(d['price'])
print(cor1)
# Out:
# 0.9215913011934771

# %%
sns.scatterplot('carat', 'price', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The Carat an price is highly corrlated

# %% [markdown]
# ### Correlation between Depth (Total Depth) and Price

# %%
cor2 = d['depth'].corr(d['price'])
print(cor2)
# Out:
# -0.010647404584142966

# %%
sns.scatterplot('depth', 'price', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Correlation between table (width of top) and Price

# %%
cor3 = d['table'].corr(d['price'])
print(cor3)
# Out:
# 0.12713390212174194

# %%
sns.scatterplot('table', 'price', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Correlation between x (Length) and Price

# %%
cor4 = d['x'].corr(d['price'])
print(cor4)
# Out:
# 0.8844351610161276

# %%
sns.scatterplot('x', 'price', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Correlation between y (width) and Price

# %%
cor5 = d['y'].corr(d['price'])
print(cor5)
# Out:
# 0.8654208978641869

# %%
sns.scatterplot('y', 'price', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Correlation between z (depth) and Price

# %%
cor6 = d['z'].corr(d['price'])
print(cor6)
# Out:
# 0.8612494438514485

# %%
sns.scatterplot('z', 'price', data=d.sample(1000));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#fig = plt.figure(figsize=(20,10))
sns.kdeplot('x', 'price', data=d.sample(1000));
sns.kdeplot('y', 'price', data=d.sample(1000));
sns.kdeplot('z', 'price', data=d.sample(1000));
sns.kdeplot('carat', 'price', data=d.sample(1000));
plt.legend(title='Dimentions', labels=['x', 'y', 'z', 'carat'], bbox_to_anchor=(1.05, 1), loc='upper left');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Finding Outliers from each variable

# %%
sns.boxplot(d.sample(5000).carat);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.sample(5000).depth);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.sample(5000).table);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.sample(5000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.sample(5000).x);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.sample(5000).y);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.sample(5000).z);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Relation between "Cut" and "Price"

# %%
d.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']

# %% [markdown]
# ### Cut - Ideal

# %%
df1= d.copy()
df1 = df1[(df1['cut'] == 'Ideal')]

# %%
df1.head()
# Out:
#     carat    cut color clarity  depth  table  price     x     y     z
# 0    0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11   0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13   0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16   0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39   0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78

# %%
df1.shape
# Out:
# (21551, 10)

# %%
df1.drop('carat', axis=1, inplace=True)

# %%
df1.drop(['color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#       cut  price
# 0   Ideal    326
# 11  Ideal    340
# 13  Ideal    344
# 16  Ideal    348
# 39  Ideal    403

# %%
df1.shape
# Out:
# (21551, 2)

# %%
mean_ideal=np.mean(df1['price'])
mean_ideal
# Out:
# 3457.541970210199

# %%
median_ideal=np.median(df1['price'])
median_ideal
# Out:
# 1810.0

# %%
df1_ = df1.copy()
df1_ = df1_[(df1_['price'] > 1810.0)]

# %%
df1_.head()
# Out:
#        cut  price
# 90   Ideal   2757
# 92   Ideal   2757
# 102  Ideal   2760
# 104  Ideal   2760
# 105  Ideal   2760

# %%
df1_.shape
# Out:
# (10774, 2)

# %%
sns.swarmplot(df1_.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 17.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df1_.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_ideal=np.max(df1['price'])
max_ideal
# Out:
# 18806

# %%
min_ideal=np.min(df1['price'])
min_ideal
# Out:
# 326

# %%
df1__ = df1.copy()
df1__ = df1__[(df1__['price'] > 15000.0)]

# %%
df1__.shape
# Out:
# (531, 2)

# %% [markdown]
# ### Cut - Premium

# %%
df2= d.copy()
df2 = df2[(df2['cut'] == 'Premium')]

# %%
df2.head()
# Out:
#     carat      cut color clarity  depth  table  price     x     y     z
# 1    0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3    0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12   0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15   0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68

# %%
df2.shape
# Out:
# (13791, 10)

# %%
df2.drop(['color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df2.drop('carat', axis=1, inplace=True)

# %%
df2.head()
# Out:
#         cut  price
# 1   Premium    326
# 3   Premium    334
# 12  Premium    342
# 14  Premium    345
# 15  Premium    345

# %%
df2.shape
# Out:
# (13791, 2)

# %%
mean_premium=np.mean(df2['price'])
mean_premium
# Out:
# 4584.2577042999055

# %%
median_premium=np.median(df2['price'])
median_premium
# Out:
# 3185.0

# %%
df2_ = df2.copy()
df2_ = df2_[(df2_['price'] > 3185.0)]

# %%
df2_.head()
# Out:
#           cut  price
# 2444  Premium   3187
# 2456  Premium   3190
# 2458  Premium   3190
# 2459  Premium   3190
# 2475  Premium   3192

# %%
df2_.shape
# Out:
# (6895, 2)

# %%
sns.swarmplot(df2_.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df2_.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_premium=np.max(df2['price'])
max_premium
# Out:
# 18823

# %%
min_premium=np.min(df2['price'])
min_premium
# Out:
# 326

# %%
df2__ = df2.copy()
df2__ = df2__[(df2__['price'] > 15000.0)]

# %%
df2__.shape
# Out:
# (587, 2)

# %% [markdown]
# ### Cut - Good

# %%
df3= d.copy()
df3 = df3[(df3['cut'] == 'Good')]

# %%
df3.head()
# Out:
#     carat   cut color clarity  depth  table  price     x     y     z
# 2    0.23  Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4    0.31  Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 10   0.30  Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 17   0.30  Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18   0.30  Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71

# %%
df3.shape
# Out:
# (4906, 10)

# %%
df3.drop(['carat', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df3.head()
# Out:
#      cut  price
# 2   Good    327
# 4   Good    335
# 10  Good    339
# 17  Good    351
# 18  Good    351

# %%
mean_good=np.mean(df3['price'])
mean_good
# Out:
# 3928.864451691806

# %%
median_good=np.median(df3['price'])
median_good
# Out:
# 3050.5

# %%
df3_ = df3.copy()
df3_ = df3_[(df3_['price'] > 3050.5)]

# %%
df3_.head()
# Out:
#        cut  price
# 1790  Good   3051
# 1820  Good   3057
# 1821  Good   3057
# 1823  Good   3058
# 1830  Good   3060

# %%
df3_.shape
# Out:
# (2453, 2)

# %%
max_good=np.max(df3['price'])
max_good
# Out:
# 18788

# %%
min_good=np.min(df3['price'])
min_good
# Out:
# 327

# %%
df3__ = df3.copy()
df3__ = df3__[(df3__['price'] > 15000.0)]

# %%
df3__.shape
# Out:
# (129, 2)

# %% [markdown]
# ### Cut - Very Good

# %%
df4= d.copy()
df4 = df4[(df4['cut'] == 'Very Good')]

# %%
df4.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 19   0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66

# %%
df4.shape
# Out:
# (12082, 10)

# %%
df4.drop(['carat', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df4.head()
# Out:
#           cut  price
# 5   Very Good    336
# 6   Very Good    336
# 7   Very Good    337
# 9   Very Good    338
# 19  Very Good    351

# %%
mean_verygood=np.mean(df4['price'])
mean_verygood
# Out:
# 3981.7598907465654

# %%
median_verygood=np.median(df4['price'])
median_verygood
# Out:
# 2648.0

# %%
df4_ = df4.copy()
df4_ = df4_[(df4_['price'] > 2648)]

# %%
df4_.head()
# Out:
#            cut  price
# 93   Very Good   2759
# 94   Very Good   2759
# 98   Very Good   2760
# 100  Very Good   2760
# 113  Very Good   2762

# %%
df4_.shape
# Out:
# (6041, 2)

# %%
max_very_good=np.max(df4['price'])
max_very_good
# Out:
# 18818

# %%
min_very_good=np.min(df4['price'])
min_very_good
# Out:
# 336

# %%
df4__ = df4.copy()
df4__ = df4__[(df4__['price'] > 15000)]

# %%
df4__.shape
# Out:
# (367, 2)

# %% [markdown]
# ### Cut - Fair

# %%
df5= d.copy()
df5 = df5[(df5['cut'] == 'Fair')]

# %%
df5.head()
# Out:
#      carat   cut color clarity  depth  table  price     x     y     z
# 8     0.22  Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 91    0.86  Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 97    0.96  Fair     F     SI2   66.3   62.0   2759  6.27  5.95  4.07
# 123   0.70  Fair     F     VS2   64.5   57.0   2762  5.57  5.53  3.58
# 124   0.70  Fair     F     VS2   65.3   55.0   2762  5.63  5.58  3.66

# %%
df5.shape
# Out:
# (1610, 10)

# %%
df5.drop(['carat', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df5.head()
# Out:
#       cut  price
# 8    Fair    337
# 91   Fair   2757
# 97   Fair   2759
# 123  Fair   2762
# 124  Fair   2762

# %%
mean_fair=np.mean(df5['price'])
mean_fair
# Out:
# 4358.757763975155

# %%
median_fair=np.median(df5['price'])
median_fair
# Out:
# 3282.0

# %%
df5_ = df5.copy()
df5_ = df5_[(df5_['price'] > 3282)]

# %%
df5_.head()
# Out:
#        cut  price
# 2913  Fair   3285
# 2926  Fair   3288
# 2934  Fair   3290
# 2948  Fair   3294
# 2959  Fair   3296

# %%
df5_.shape
# Out:
# (804, 2)

# %%
df5__ = df5.copy()
df5__ = df5__[(df5__['price'] > 15000)]

# %%
df5__.head()
# Out:
#         cut  price
# 25899  Fair  15030
# 25966  Fair  15152
# 26066  Fair  15282
# 26091  Fair  15330
# 26099  Fair  15351

# %%
df5__.shape
# Out:
# (41, 2)

# %%
sns.swarmplot(df5.price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 40.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df5.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_fair=np.max(df5['price'])
max_fair
# Out:
# 18574

# %%
min_fair=np.min(df5['price'])
min_fair
# Out:
# 337

# %% [markdown]
# ### Summary of relation between "Cut" and "Price"

# %%
cut_mean = pd.Series([mean_ideal, mean_premium, mean_good, mean_verygood, mean_fair],
                 index=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'])
cut_median = pd.Series([median_ideal, median_premium, median_good, median_verygood, median_fair],
                     index=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'])
cut_max = pd.Series([max_ideal, max_premium, max_good, max_very_good, max_fair],
                     index=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'])
cut_min = pd.Series([min_ideal, min_premium, min_good, min_very_good, min_fair],
                     index=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'])
cut_total_dimonds = pd.Series([21551, 13791, 4906, 12082, 1610],
                     index=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'])
# Dimonds worth of cost of 15000 USD or more
cut_costly_dimonds = pd.Series([531, 587, 129, 367, 41],
                     index=['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'])

# %%
cut_summary = pd.DataFrame({'Mean(Price)': cut_mean, 'Median(Price)': cut_median, 'Maximum Cost': cut_max, 'Minimum Cost': cut_min, 'Total Dimonds': cut_total_dimonds, 'Costly Dimonds': cut_costly_dimonds})

# %%
cut_summary
# Out:
#            Mean(Price)  Median(Price)  ...  Total Dimonds  Costly Dimonds
# Ideal      3457.541970         1810.0  ...          21551             531
# Premium    4584.257704         3185.0  ...          13791             587
# Good       3928.864452         3050.5  ...           4906             129
# Very Good  3981.759891         2648.0  ...          12082             367
# Fair       4358.757764         3282.0  ...           1610              41
#
# [5 rows x 6 columns]

# %%
sns.heatmap(cut_summary);

# %%
#cut_summary['Percetage'] = (cut_summary['Total Dimonds'] / cut_summary['Costly Dimonds'].sum()) * 100
cut_summary['Percetage'] = cut_summary['Costly Dimonds'] * 100/ cut_summary['Total Dimonds']

# %%
cut_summary
# Out:
#            Mean(Price)  Median(Price)  ...  Costly Dimonds  Percetage
# Ideal      3457.541970         1810.0  ...             531   2.463923
# Premium    4584.257704         3185.0  ...             587   4.256399
# Good       3928.864452         3050.5  ...             129   2.629433
# Very Good  3981.759891         2648.0  ...             367   3.037577
# Fair       4358.757764         3282.0  ...              41   2.546584
#
# [5 rows x 7 columns]

# %%
sns.heatmap(cut_summary);

# %% [markdown]
# ## Relation between "Color" and "Price"

# %%
d.color.unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['E', 'I', 'J', 'H', 'F', 'G', 'D']

# %% [markdown]
# ### Color - 'E'

# %%
df11= d.copy()
df11 = df11[(df11['color'] == 'E')]

# %%
df11.head()
# Out:
#     carat      cut color clarity  depth  table  price     x     y     z
# 0    0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 8    0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 14   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27

# %%
df11.shape
# Out:
# (9797, 10)

# %%
df11.drop('carat', axis=1, inplace=True)

# %%
df11.drop(['cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df11.head()
# Out:
#    color  price
# 0      E    326
# 1      E    326
# 2      E    327
# 8      E    337
# 14     E    345

# %%
df11.shape
# Out:
# (9797, 2)

# %%
mean_E=np.mean(df11['price'])
mean_E
# Out:
# 3076.7524752475247

# %%
median_E=np.median(df11['price'])
median_E
# Out:
# 1739.0

# %%
df11_ = df11.copy()
df11_ = df11_[(df11_['price'] > 1810.0)]

# %%
df11_.head()
# Out:
#    color  price
# 90     E   2757
# 91     E   2757
# 93     E   2759
# 95     E   2759
# 98     E   2760

# %%
df11_.shape
# Out:
# (4721, 2)

# %%
sns.swarmplot(df11_.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 21.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df11_.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_E=np.max(df11['price'])
max_E
# Out:
# 18731

# %%
min_E=np.min(df11['price'])
min_E
# Out:
# 326

# %%
df11__ = df11.copy()
df11__ = df11__[(df11__['price'] > 15000.0)]

# %%
df11__.shape
# Out:
# (161, 2)

# %% [markdown]
# ### Color - I

# %%
df12= d.copy()
df12 = df12[(df12['color'] == 'I')]

# %%
df12.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 16   0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 20   0.30       Good     I     SI2   63.3   56.0    351  4.26  4.30  2.71
# 26   0.24    Premium     I     VS1   62.5   57.0    355  3.97  3.94  2.47

# %%
df12.shape
# Out:
# (5422, 10)

# %%
df12.drop(['cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df12.drop('carat', axis=1, inplace=True)

# %%
df12.head()
# Out:
#    color  price
# 3      I    334
# 6      I    336
# 16     I    348
# 20     I    351
# 26     I    355

# %%
df12.shape
# Out:
# (5422, 2)

# %%
mean_I=np.mean(df12['price'])
mean_I
# Out:
# 5091.874953891553

# %%
median_I=np.median(df12['price'])
median_I
# Out:
# 3730.0

# %%
df12_ = df12.copy()
df12_ = df12_[(df12_['price'] > 3185.0)]

# %%
df12_.head()
# Out:
#      color  price
# 2459     I   3190
# 2492     I   3196
# 2518     I   3201
# 2556     I   3209
# 2568     I   3211

# %%
df12_.shape
# Out:
# (2941, 2)

# %%
sns.swarmplot(df12_.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df12_.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_I=np.max(df12['price'])
max_I
# Out:
# 18823

# %%
min_I=np.min(df12['price'])
min_I
# Out:
# 334

# %%
df12__ = df12.copy()
df12__ = df12__[(df12__['price'] > 15000.0)]

# %%
df12__.shape
# Out:
# (369, 2)

# %% [markdown]
# ### Color - J

# %%
df13= d.copy()
df13 = df13[(df13['color'] == 'J')]

# %%
df13.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13   0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71

# %%
df13.shape
# Out:
# (2808, 10)

# %%
df13.drop(['carat', 'cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df13.head()
# Out:
#    color  price
# 4      J    335
# 5      J    336
# 10     J    339
# 11     J    340
# 13     J    344

# %%
mean_J=np.mean(df13['price'])
mean_J
# Out:
# 5323.81801994302

# %%
median_J=np.median(df13['price'])
median_J
# Out:
# 4234.0

# %%
df13_ = df13.copy()
df13_ = df13_[(df13_['price'] > 3050.5)]

# %%
df13_.head()
# Out:
#      color  price
# 1825     J   3058
# 1834     J   3061
# 1843     J   3062
# 1869     J   3070
# 1906     J   3080

# %%
df13_.shape
# Out:
# (1761, 2)

# %%
max_J=np.max(df13['price'])
max_J
# Out:
# 18710

# %%
min_J=np.min(df13['price'])
min_J
# Out:
# 335

# %%
df13__ = df13.copy()
df13__ = df13__[(df13__['price'] > 15000.0)]

# %%
df13__.shape
# Out:
# (121, 2)

# %% [markdown]
# ### Color - H

# %%
df14= d.copy()
df14 = df14[(df14['color'] == 'H')]

# %%
df14.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 22   0.23  Very Good     H     VS1   61.0   57.0    353  3.94  3.96  2.41
# 37   0.31       Good     H     SI1   64.0   54.0    402  4.29  4.31  2.75
# 44   0.32       Good     H     SI2   63.1   56.0    403  4.34  4.37  2.75

# %%
df14.shape
# Out:
# (8304, 10)

# %%
df14.drop(['carat', 'cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df14.head()
# Out:
#    color  price
# 7      H    337
# 9      H    338
# 22     H    353
# 37     H    402
# 44     H    403

# %%
mean_H=np.mean(df14['price'])
mean_H
# Out:
# 4486.669195568401

# %%
median_H=np.median(df14['price'])
median_H
# Out:
# 3460.0

# %%
df14_ = df14.copy()
df14_ = df14_[(df14_['price'] > 2648)]

# %%
df14_.head()
# Out:
#     color  price
# 99      H   2760
# 126     H   2763
# 128     H   2763
# 129     H   2763
# 130     H   2763

# %%
df14_.shape
# Out:
# (4638, 2)

# %%
max_H=np.max(df14['price'])
max_H
# Out:
# 18803

# %%
min_H=np.min(df14['price'])
min_H
# Out:
# 337

# %%
df14__ = df14.copy()
df14__ = df14__[(df14__['price'] > 15000)]

# %%
df14__.shape
# Out:
# (319, 2)

# %% [markdown]
# ### Color - F

# %%
df15= d.copy()
df15 = df15[(df15['color'] == 'F')]

# %%
df15.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 29   0.23  Very Good     F     VS1   60.9   57.0    357  3.96  3.99  2.42
# 30   0.23  Very Good     F     VS1   60.0   57.0    402  4.00  4.03  2.41
# 31   0.23  Very Good     F     VS1   59.8   57.0    402  4.04  4.06  2.42
# 35   0.23       Good     F     VS1   58.2   59.0    402  4.06  4.08  2.37

# %%
df15.shape
# Out:
# (9542, 10)

# %%
df15.drop(['carat', 'cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df15.head()
# Out:
#    color  price
# 12     F    342
# 29     F    357
# 30     F    402
# 31     F    402
# 35     F    402

# %%
mean_F=np.mean(df15['price'])
mean_F
# Out:
# 3724.886396981765

# %%
median_F=np.median(df15['price'])
median_F
# Out:
# 2343.5

# %%
df15_ = df15.copy()
df15_ = df15_[(df15_['price'] > 3282)]

# %%
df15_.head()
# Out:
#      color  price
# 2900     F   3283
# 2905     F   3283
# 2908     F   3284
# 2912     F   3285
# 2914     F   3285

# %%
df15_.shape
# Out:
# (3690, 2)

# %%
df15__ = df15.copy()
df15__ = df15__[(df15__['price'] > 15000)]

# %%
df15__.head()
# Out:
#       color  price
# 25886     F  15005
# 25892     F  15017
# 25893     F  15022
# 25898     F  15026
# 25901     F  15031

# %%
df15__.shape
# Out:
# (232, 2)

# %%
sns.swarmplot(df15.price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 80.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df15.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_F=np.max(df15['price'])
max_F
# Out:
# 18791

# %%
min_F=np.min(df15['price'])
min_F
# Out:
# 342

# %% [markdown]
# ### Color - G

# %%
df16= d.copy()
df16 = df16[(df16['color'] == 'G')]

# %%
df16.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 25   0.23  Very Good     G    VVS2   60.4   58.0    354  3.97  4.01  2.41
# 51   0.23      Ideal     G     VS1   61.9   54.0    404  3.93  3.95  2.44
# 65   0.28      Ideal     G    VVS2   61.4   56.0    553  4.19  4.22  2.58
# 67   0.31  Very Good     G     SI1   63.3   57.0    553  4.33  4.30  2.73
# 68   0.31    Premium     G     SI1   61.8   58.0    553  4.35  4.32  2.68

# %%
df16.shape
# Out:
# (11292, 10)

# %%
df16.drop(['carat', 'cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df16.head()
# Out:
#    color  price
# 25     G    354
# 51     G    404
# 65     G    553
# 67     G    553
# 68     G    553

# %%
mean_G=np.mean(df16['price'])
mean_G
# Out:
# 3999.135671271697

# %%
median_G=np.median(df16['price'])
median_G
# Out:
# 2242.0

# %%
df16__ = df16.copy()
df16__ = df16__[(df16__['price'] > 15000)]

# %%
df16__.head()
# Out:
#       color  price
# 25889     G  15013
# 25890     G  15014
# 25891     G  15014
# 25894     G  15025
# 25907     G  15038

# %%
df16__.shape
# Out:
# (333, 2)

# %%
sns.swarmplot(df16.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df16.sample(1000).price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_G=np.max(df16['price'])
max_G
# Out:
# 18818

# %%
min_G=np.min(df16['price'])
min_G
# Out:
# 354

# %% [markdown]
# ### Color - D

# %%
df17= d.copy()
df17 = df17[(df17['color'] == 'D')]

# %%
df17.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 28   0.23  Very Good     D     VS2   60.5   61.0    357  3.96  3.97  2.40
# 34   0.23  Very Good     D     VS1   61.9   58.0    402  3.92  3.96  2.44
# 38   0.26  Very Good     D     VS2   60.8   59.0    403  4.13  4.16  2.52
# 42   0.26       Good     D     VS2   65.2   56.0    403  3.99  4.02  2.61
# 43   0.26       Good     D     VS1   58.4   63.0    403  4.19  4.24  2.46

# %%
df17.shape
# Out:
# (6775, 10)

# %%
df17.drop(['carat', 'cut', 'clarity', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df17.head()
# Out:
#    color  price
# 28     D    357
# 34     D    402
# 38     D    403
# 42     D    403
# 43     D    403

# %%
mean_D=np.mean(df17['price'])
mean_D
# Out:
# 3169.9540959409596

# %%
median_D=np.median(df17['price'])
median_D
# Out:
# 1838.0

# %%
df17__ = df17.copy()
df17__ = df17__[(df17__['price'] > 15000)]

# %%
df17__.head()
# Out:
#       color  price
# 25888     D  15011
# 25911     D  15052
# 25924     D  15081
# 25925     D  15081
# 25937     D  15100

# %%
df17__.shape
# Out:
# (120, 2)

# %%
sns.swarmplot(df17.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 34.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df17.sample(1000).price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_D=np.max(df17['price'])
max_D
# Out:
# 18693

# %%
min_D=np.min(df17['price'])
min_D
# Out:
# 357

# %% [markdown]
# ### Summary of relation between "Color" and "Price"

# %%
color_mean = pd.Series([mean_E, mean_I, mean_J, mean_H, mean_F, mean_G, mean_D],
                 index=['E', 'I', 'J', 'H', 'F', 'G', 'D'])
color_median = pd.Series([median_E, median_I, median_J, median_H, median_F, median_G, median_D],
                     index=['E', 'I', 'J', 'H', 'F', 'G', 'D'])
color_max = pd.Series([max_E, max_I, max_J, max_H, max_F, max_G, max_D],
                     index=['E', 'I', 'J', 'H', 'F', 'G', 'D'])
color_min = pd.Series([min_E, min_I, min_J, min_H, min_F, min_G, min_D],
                     index=['E', 'I', 'J', 'H', 'F', 'G', 'D'])
color_total_dimonds = pd.Series([4721,5422, 2808, 8304, 9542, 11292, 6775],
                     index=['E', 'I', 'J', 'H', 'F', 'G', 'D'])
# Dimonds worth of cost of 15000 USD or more
color_costly_dimonds = pd.Series([161, 369, 121, 319, 232, 333, 120],
                     index=['E', 'I', 'J', 'H', 'F', 'G', 'D'])

# %%
color_summary = pd.DataFrame({'Mean(Price)': color_mean, 'Median(Price)': color_median, 'Maximum Cost': color_max, 'Minimum Cost': color_min, 'Total Dimonds': color_total_dimonds, 'Costly Dimonds': color_costly_dimonds})

# %%
color_summary
# Out:
#    Mean(Price)  Median(Price)  ...  Total Dimonds  Costly Dimonds
# E  3076.752475         1739.0  ...           4721             161
# I  5091.874954         3730.0  ...           5422             369
# J  5323.818020         4234.0  ...           2808             121
# H  4486.669196         3460.0  ...           8304             319
# F  3724.886397         2343.5  ...           9542             232
# G  3999.135671         2242.0  ...          11292             333
# D  3169.954096         1838.0  ...           6775             120
#
# [7 rows x 6 columns]

# %%
sns.heatmap(color_summary);

# %%
#cut_summary['Percetage'] = (cut_summary['Total Dimonds'] / cut_summary['Costly Dimonds'].sum()) * 100
color_summary['Percetage'] = color_summary['Costly Dimonds'] * 100/ color_summary['Total Dimonds']

# %%
color_summary
# Out:
#    Mean(Price)  Median(Price)  ...  Costly Dimonds  Percetage
# E  3076.752475         1739.0  ...             161   3.410294
# I  5091.874954         3730.0  ...             369   6.805607
# J  5323.818020         4234.0  ...             121   4.309117
# H  4486.669196         3460.0  ...             319   3.841522
# F  3724.886397         2343.5  ...             232   2.431356
# G  3999.135671         2242.0  ...             333   2.948990
# D  3169.954096         1838.0  ...             120   1.771218
#
# [7 rows x 7 columns]

# %%
sns.heatmap(color_summary);

# %% [markdown]
# ## Relation between "Clarity" and "Price"

# %%
d.clarity.unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']

# %% [markdown]
# ### Clarity - 'SI2'

# %%
df21= d.copy()
df21 = df21[(df21['clarity'] == 'SI2')]

# %%
df21.head()
# Out:
#     carat      cut color clarity  depth  table  price     x     y     z
# 0    0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 4    0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 13   0.31    Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 16   0.30    Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68

# %%
df21.shape
# Out:
# (9194, 10)

# %%
df21.drop('carat', axis=1, inplace=True)

# %%
df21.drop(['cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df21.head()
# Out:
#    clarity  price
# 0      SI2    326
# 4      SI2    335
# 13     SI2    344
# 14     SI2    345
# 16     SI2    348

# %%
df21.shape
# Out:
# (9194, 2)

# %%
mean_SI2=np.mean(df21['price'])
mean_SI2
# Out:
# 5063.028605612356

# %%
median_SI2=np.median(df21['price'])
median_SI2
# Out:
# 4072.0

# %%
sns.swarmplot(df21.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 22.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df21.sample(1000).price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_SI2=np.max(df21['price'])
max_SI2
# Out:
# 18804

# %%
min_SI2=np.min(df21['price'])
min_SI2
# Out:
# 326

# %%
df21__ = df21.copy()
df21__ = df21__[(df21__['price'] > 15000.0)]

# %%
df21__.shape
# Out:
# (518, 2)

# %% [markdown]
# ### Clarity - SI1

# %%
df22= d.copy()
df22 = df22[(df22['clarity'] == 'SI1')]

# %%
df22.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 17   0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70

# %%
df22.shape
# Out:
# (13065, 10)

# %%
df22.drop(['cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df22.drop('carat', axis=1, inplace=True)

# %%
df22.head()
# Out:
#    clarity  price
# 1      SI1    326
# 7      SI1    337
# 10     SI1    339
# 12     SI1    342
# 17     SI1    351

# %%
df22.shape
# Out:
# (13065, 2)

# %%
mean_SI1=np.mean(df22['price'])
mean_SI1
# Out:
# 3996.001148105626

# %%
median_SI1=np.median(df22['price'])
median_SI1
# Out:
# 2822.0

# %%
sns.swarmplot(df22.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df22.sample(1000).price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_SI1=np.max(df22['price'])
max_SI1
# Out:
# 18818

# %%
min_SI1=np.min(df22['price'])
min_SI1
# Out:
# 326

# %%
df22__ = df22.copy()
df22__ = df22__[(df22__['price'] > 15000.0)]

# %%
df22__.shape
# Out:
# (364, 2)

# %% [markdown]
# ### Clarity - VS1

# %%
df23= d.copy()
df23 = df23[(df23['clarity'] == 'VS1')]

# %%
df23.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 22   0.23  Very Good     H     VS1   61.0   57.0    353  3.94  3.96  2.41
# 26   0.24    Premium     I     VS1   62.5   57.0    355  3.97  3.94  2.47

# %%
df23.shape
# Out:
# (8171, 10)

# %%
df23.drop(['carat', 'cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df23.head()
# Out:
#    clarity  price
# 2      VS1    327
# 9      VS1    338
# 11     VS1    340
# 22     VS1    353
# 26     VS1    355

# %%
mean_VS1=np.mean(df23['price'])
mean_VS1
# Out:
# 3839.4553910170116

# %%
median_VS1=np.median(df23['price'])
median_VS1
# Out:
# 2005.0

# %%
max_VS1=np.max(df23['price'])
max_VS1
# Out:
# 18795

# %%
min_VS1=np.min(df23['price'])
min_VS1
# Out:
# 327

# %%
df23__ = df23.copy()
df23__ = df23__[(df23__['price'] > 15000.0)]

# %%
df23__.shape
# Out:
# (227, 2)

# %% [markdown]
# ### Clarity - VS2

# %%
df24= d.copy()
df24 = df24[(df24['clarity'] == 'VS2')]

# %%
df24.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 21   0.23  Very Good     E     VS2   63.8   55.0    352  3.85  3.92  2.48
# 27   0.30  Very Good     J     VS2   62.2   57.0    357  4.28  4.30  2.67
# 28   0.23  Very Good     D     VS2   60.5   61.0    357  3.96  3.97  2.40

# %%
df24.shape
# Out:
# (12258, 10)

# %%
df24.drop(['carat', 'cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df24.head()
# Out:
#    clarity  price
# 3      VS2    334
# 8      VS2    337
# 21     VS2    352
# 27     VS2    357
# 28     VS2    357

# %%
mean_VS2=np.mean(df24['price'])
mean_VS2
# Out:
# 3924.989394681025

# %%
median_VS2=np.median(df24['price'])
median_VS2
# Out:
# 2054.0

# %%
max_VS2=np.max(df24['price'])
max_VS2
# Out:
# 18823

# %%
min_VS2=np.min(df24['price'])
min_VS2
# Out:
# 334

# %%
df24__ = df24.copy()
df24__ = df24__[(df24__['price'] > 15000)]

# %%
df24__.shape
# Out:
# (358, 2)

# %% [markdown]
# ### Clarity - VVS2

# %%
df25= d.copy()
df25 = df25[(df25['clarity'] == 'VVS2')]

# %%
df25.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 25   0.23  Very Good     G    VVS2   60.4   58.0    354  3.97  4.01  2.41
# 65   0.28      Ideal     G    VVS2   61.4   56.0    553  4.19  4.22  2.58
# 75   0.26  Very Good     F    VVS2   59.2   60.0    554  4.19  4.22  2.49
# 76   0.26  Very Good     E    VVS2   59.9   58.0    554  4.15  4.23  2.51

# %%
df25.shape
# Out:
# (5066, 10)

# %%
df25.drop(['carat', 'cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df25.head()
# Out:
#    clarity  price
# 5     VVS2    336
# 25    VVS2    354
# 65    VVS2    553
# 75    VVS2    554
# 76    VVS2    554

# %%
mean_VVS2=np.mean(df25['price'])
mean_VVS2
# Out:
# 3283.737070667193

# %%
median_VVS2=np.median(df25['price'])
median_VVS2
# Out:
# 1311.0

# %%
df25__ = df25.copy()
df25__ = df25__[(df25__['price'] > 15000)]

# %%
df25__.head()
# Out:
#       clarity  price
# 25889    VVS2  15013
# 25901    VVS2  15031
# 25914    VVS2  15059
# 25922    VVS2  15076
# 25944    VVS2  15110

# %%
df25__.shape
# Out:
# (78, 2)

# %%
sns.swarmplot(df25.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df25.sample(1000).price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_VVS2=np.max(df25['price'])
max_VVS2
# Out:
# 18768

# %%
min_VVS2=np.min(df25['price'])
min_VVS2
# Out:
# 336

# %% [markdown]
# ### Clarity - VVS1

# %%
df26= d.copy()
df26 = df26[(df26['clarity'] == 'VVS1')]

# %%
df26.head()
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 66   0.32      Ideal     I    VVS1   62.0   55.3    553  4.39  4.42  2.73
# 69   0.24    Premium     E    VVS1   60.7   58.0    553  4.01  4.03  2.44
# 70   0.24  Very Good     D    VVS1   61.5   60.0    553  3.97  4.00  2.45
# 79   0.26  Very Good     E    VVS1   62.6   59.0    554  4.06  4.09  2.55

# %%
df26.shape
# Out:
# (3655, 10)

# %%
df26.drop(['carat', 'cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df26.head()
# Out:
#    clarity  price
# 6     VVS1    336
# 66    VVS1    553
# 69    VVS1    553
# 70    VVS1    553
# 79    VVS1    554

# %%
mean_VVS1=np.mean(df26['price'])
mean_VVS2
# Out:
# 3283.737070667193

# %%
median_VVS1=np.median(df26['price'])
median_VVS1
# Out:
# 1093.0

# %%
df26__ = df26.copy()
df26__ = df26__[(df26__['price'] > 15000)]

# %%
df26__.head()
# Out:
#       clarity  price
# 25886    VVS1  15005
# 25898    VVS1  15026
# 25954    VVS1  15134
# 25982    VVS1  15185
# 26045    VVS1  15247

# %%
df26__.shape
# Out:
# (50, 2)

# %%
sns.swarmplot(df26.sample(1000).price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 54.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df26.sample(1000).price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_VVS1=np.max(df26['price'])
max_VVS1
# Out:
# 18777

# %%
min_VVS1=np.min(df26['price'])
min_VVS1
# Out:
# 336

# %% [markdown]
# ### Clarity - I1

# %%
df27= d.copy()
df27 = df27[(df27['clarity'] == 'I1')]

# %%
df27.head()
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 15    0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 172   1.17  Very Good     J      I1   60.2   61.0   2774  6.83  6.90  4.13
# 215   1.01    Premium     F      I1   61.8   60.0   2781  6.39  6.36  3.94
# 241   1.01       Fair     E      I1   64.5   58.0   2788  6.29  6.21  4.03
# 315   0.96      Ideal     F      I1   60.7   55.0   2801  6.37  6.41  3.88

# %%
df27.shape
# Out:
# (741, 10)

# %%
df27.drop(['carat', 'cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df27.head()
# Out:
#     clarity  price
# 15       I1    345
# 172      I1   2774
# 215      I1   2781
# 241      I1   2788
# 315      I1   2801

# %%
mean_I1=np.mean(df27['price'])
mean_I1
# Out:
# 3924.1686909581645

# %%
median_I1=np.median(df27['price'])
median_I1
# Out:
# 3344.0

# %%
df27__ = df27.copy()
df27__ = df27__[(df27__['price'] > 15000)]

# %%
df27__.head()
# Out:
#       clarity  price
# 25998      I1  15223
# 25999      I1  15223
# 26431      I1  15964
# 26444      I1  15984
# 26534      I1  16193

# %%
df27__.shape
# Out:
# (9, 2)

# %%
sns.swarmplot(df27.price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 15.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df27.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_I1=np.max(df27['price'])
max_I1
# Out:
# 18531

# %%
min_I1=np.min(df27['price'])
min_I1
# Out:
# 345

# %% [markdown]
# ### Clarity - IF

# %%
df28 = d.copy()
df28 = df28[(df28['clarity'] == 'IF')]

# %%
df28.head()
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 229   0.52      Ideal     F      IF   62.2   55.0   2783  5.14  5.18  3.21
# 250   0.55      Ideal     G      IF   60.9   57.0   2789  5.28  5.30  3.22
# 256   0.64      Ideal     G      IF   61.3   56.0   2790  5.54  5.58  3.41
# 281   0.72    Premium     I      IF   63.0   57.0   2795  5.72  5.70  3.60
# 304   0.60  Very Good     G      IF   61.6   56.0   2800  5.43  5.46  3.35

# %%
df28.shape
# Out:
# (1790, 10)

# %%
df28.drop(['carat', 'cut', 'color', 'depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)

# %%
df28.head()
# Out:
#     clarity  price
# 229      IF   2783
# 250      IF   2789
# 256      IF   2790
# 281      IF   2795
# 304      IF   2800

# %%
mean_IF=np.mean(df28['price'])
mean_IF
# Out:
# 2864.839106145251

# %%
median_IF=np.median(df28['price'])
median_IF
# Out:
# 1080.0

# %%
df28__ = df28.copy()
df28__ = df28__[(df28__['price'] > 15000)]

# %%
df28__.head()
# Out:
#       clarity  price
# 25924      IF  15081
# 25925      IF  15081
# 25972      IF  15164
# 25986      IF  15193
# 25997      IF  15219

# %%
df28__.shape
# Out:
# (51, 2)

# %%
sns.swarmplot(df28.price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 62.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df28.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
max_IF=np.max(df28['price'])
max_IF
# Out:
# 18806

# %%
min_IF=np.min(df28['price'])
min_IF
# Out:
# 369

# %% [markdown]
# ### Summary of relation between "Clarity" and "Price"

# %%
clarity_mean = pd.Series([mean_SI2, mean_SI1, mean_VS1, mean_VS2, mean_VVS2, mean_VVS1, mean_I1, mean_IF],
                 index=['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'])
clarity_median = pd.Series([median_SI2, median_SI1, median_VS1, median_VS2, median_VVS2, median_VVS1, median_I1, median_IF],
                     index=['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'])
clarity_max = pd.Series([max_SI2, max_SI1, max_VS1, max_VS2, max_VVS2, max_VVS1, max_I1, max_IF],
                     index=['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'])
clarity_min = pd.Series([min_SI2, min_SI1, min_VS1, min_VS2, min_VVS2, min_VVS1, min_I1, min_IF],
                     index=['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'])
clarity_total_dimonds = pd.Series([9194, 13065, 8171, 12258, 5066, 3655, 741, 1790],
                     index=['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'])
# Dimonds worth of cost of 15000 USD or more
clarity_costly_dimonds = pd.Series([518, 364, 227, 358, 78, 50, 9, 51],
                     index=['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'])

# %%
clarity_summary = pd.DataFrame({'Mean(Price)': clarity_mean, 'Median(Price)': clarity_median, 'Maximum Cost': clarity_max, 'Minimum Cost': clarity_min, 'Total Dimonds': clarity_total_dimonds, 'Costly Dimonds': clarity_costly_dimonds})

# %%
clarity_summary
# Out:
#       Mean(Price)  Median(Price)  ...  Total Dimonds  Costly Dimonds
# SI2   5063.028606         4072.0  ...           9194             518
# SI1   3996.001148         2822.0  ...          13065             364
# VS1   3839.455391         2005.0  ...           8171             227
# VS2   3924.989395         2054.0  ...          12258             358
# VVS2  3283.737071         1311.0  ...           5066              78
# VVS1  2523.114637         1093.0  ...           3655              50
# I1    3924.168691         3344.0  ...            741               9
# IF    2864.839106         1080.0  ...           1790              51
#
# [8 rows x 6 columns]

# %%
sns.heatmap(clarity_summary);

# %%
#cut_summary['Percetage'] = (cut_summary['Total Dimonds'] / cut_summary['Costly Dimonds'].sum()) * 100
clarity_summary['Percetage'] = clarity_summary['Costly Dimonds'] * 100/ clarity_summary['Total Dimonds']

# %%
clarity_summary
# Out:
#       Mean(Price)  Median(Price)  ...  Costly Dimonds  Percetage
# SI2   5063.028606         4072.0  ...             518   5.634109
# SI1   3996.001148         2822.0  ...             364   2.786070
# VS1   3839.455391         2005.0  ...             227   2.778118
# VS2   3924.989395         2054.0  ...             358   2.920542
# VVS2  3283.737071         1311.0  ...              78   1.539676
# VVS1  2523.114637         1093.0  ...              50   1.367989
# I1    3924.168691         3344.0  ...               9   1.214575
# IF    2864.839106         1080.0  ...              51   2.849162
#
# [8 rows x 7 columns]

# %%
sns.heatmap(clarity_summary);

# %% [markdown]
# ## Hypothesis Testing
#
# https://christopherduquet.com/diamond-pricing-guide/
#
# **Null Hypothesis:** Dimond with higher Cost (12000-18000 USD) are made with 3.0 caret or moe.
#
# Alternative Hypothesis: Dimond with higher Cost (12000-18000 USD) are not made with 3.0 caret or moe.

# %%
df_ht = d.copy()
df_ht = df_ht[(df_ht['price'] > 12000)]
#& (df_ht['carat'] > 3.0)

# %%
df_ht.head()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 23897   1.57      Ideal     H     VS2   61.8   55.0  12004  7.45  7.49  4.62
# 23898   1.50  Very Good     G     VS1   63.4   59.0  12005  7.25  7.19  4.58
# 23899   1.31      Ideal     G     VS1   61.6   57.0  12008  6.99  7.04  4.32
# 23900   1.50      Ideal     G     SI1   61.0   57.0  12009  7.38  7.41  4.51
# 23901   1.75  Very Good     D     SI2   60.7   57.0  12012  7.78  7.83  4.74

# %%
sample = df_ht.sample(10)

# %%
print(df_ht.shape)
print(sample.shape)
# Out:
# (3463, 10)
# (10, 10)

# %%
mean_ht=np.mean(sample['carat'])
mean_ht
# Out:
# 1.7349999999999999

# %%
median_ht=np.median(sample['carat'])
median_ht
# Out:
# 1.625

# %%
#Compute the number of sample
index=sample.index
n=len(index)
#print(index)
print(n)
# Out:
# 10

# %%
#Compute Standard Dviation - as we are unaware aboyt population variance
stddev = np.std(sample['carat'], ddof=1)
#stddev1 = df_ht['carat'].std()
print(stddev)
#print(stddev1)
# Out:
# 0.29186183946061417

# %%
from math import sqrt
from scipy.stats import t

#Given
mu_0 = 3.0

#Compute test statistic
t_statistic = (mean_ht - mu_0)/(stddev/sqrt(n))

#Set alpha
alpha = 0.05
t_critical = t.ppf(1 - alpha, n-1)
p_value = (1.0 - t.cdf(np.abs(t_statistic), 1))

print('Sample Size:',n)
print('t-sattistics value:',t_statistic)
print('t_critical Value:',t_critical)
print('SD:', stddev)

if (np.abs(t_statistic) >  t_critical) :
  print ('Reject Null Hypothesis: p-value = ', p_value, ' alpha = ', alpha)
else :
  print ('Not enough evidence to reject Null Hypothesis: p_value = ', p_value, ' alpha = ', alpha)
# Out:
# Sample Size: 10
# t-sattistics value: -13.706078353737045
# t_critical Value: 1.8331129326536335
# SD: 0.29186183946061417
# Reject Null Hypothesis: p-value =  0.023182916733474168  alpha =  0.05

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import t
from scipy.stats import chi2

x_min =  -4
x_max = 10

mean = 0
std = 1

x = np.linspace(x_min, x_max, 100)

y = t.pdf(x, 2)

ax = plt.gca()

plt.xlim(x_min,x_max)
plt.ylim(0,0.7)

plt.plot(x,y)

x2 = np.linspace(1.65, 10, 100)
y2 = t.pdf(x2, 2)
plt.fill_between(x2, y2, color='orange', alpha=0.5)

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('AU2049007.ipynb')
# Out:
# File ‘colab_pdf.py’ already there; not retrieving.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/My Drive/Colab Notebooks/AU2049007.ipynb to pdf
# [NbConvertApp] Support files will be in AU2049007_files/
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Making directory ./AU2049007_files
# [NbConvertApp] Writing 302851 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 1228516 bytes to /content/drive/My Drive/AU2049007.pdf
# 'File ready to be Downloaded and Saved to Drive'
